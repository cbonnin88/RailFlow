# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/RailFlow/blob/main/Product_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import polars as pl
import plotly.express as px

# %%
# Loading the Data
df_searches = pl.read_csv('clean_searches.csv')
df_bookings = pl.read_csv('clean_bookings.csv')
df_users = pl.read_csv('clean_users.csv')

# %%
df_searches.head()
# Out:
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ search_id  ┆ user_id    ┆ timestamp  ┆ origin_st ┆ destinati ┆ passenger ┆ departure ┆ depature_ │
# │ ---        ┆ ---        ┆ ---        ┆ ation     ┆ on_statio ┆ _count    ┆ _date     ┆ date      │
# │ str        ┆ str        ┆ str        ┆ ---       ┆ n         ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆            ┆ str       ┆ ---       ┆ i64       ┆ str       ┆ str       │
# │            ┆            ┆            ┆           ┆ str       ┆           ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ fba4f473-c ┆ d09d81e5-e ┆ 2025-05-10 ┆ Nantes    ┆ Strasbour ┆ 1         ┆ 2025-05-3 ┆ null      │
# │ 45c-44cb-a ┆ 17a-416c-b ┆ T11:53:09. ┆           ┆ g         ┆           ┆ 0T11:53:0 ┆           │
# │ 180-f1f0c5 ┆ 37a-a69be0 ┆ 000000     ┆           ┆           ┆           ┆ 9.419189  ┆           │
# │ …          ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ e979d7ef-1 ┆ bfcade59-8 ┆ 2025-01-18 ┆ Marseille ┆ Nantes    ┆ 1         ┆ 2025-01-2 ┆ null      │
# │ c14-4bd7-b ┆ 0f8-4618-9 ┆ T02:45:56. ┆ St-Charle ┆           ┆           ┆ 3T02:45:5 ┆           │
# │ 19e-fbf76b ┆ ccc-de44a7 ┆ 746525     ┆ s         ┆           ┆           ┆ 6.746525  ┆           │
# │ …          ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 529b14cb-0 ┆ 0f2b800f-9 ┆ 2025-05-14 ┆ Lyon      ┆ Nantes    ┆ 2         ┆ 2025-05-2 ┆ null      │
# │ ed5-4ee0-9 ┆ f10-433e-9 ┆ T06:00:00. ┆ Part-Dieu ┆           ┆           ┆ 1T06:00:0 ┆           │
# │ 228-e4a84d ┆ 998-06d95e ┆ 490315     ┆           ┆           ┆           ┆ 0.490315  ┆           │
# │ …          ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 1b905016-8 ┆ 5eab057d-2 ┆ 2025-07-03 ┆ Bordeaux  ┆ Bordeaux  ┆ 3         ┆ 2025-08-0 ┆ null      │
# │ e6c-4ea4-b ┆ 8fa-4bcb-b ┆ T02:35:23. ┆ St-Jean   ┆ St-Jean   ┆           ┆ 1T02:35:2 ┆           │
# │ 96c-b4b9e8 ┆ 1ab-a08a2c ┆ 365211     ┆           ┆           ┆           ┆ 3.365211  ┆           │
# │ …          ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ 10bbab91-5 ┆ 64f51332-1 ┆ 2025-10-31 ┆ Lille     ┆ Paris     ┆ 1         ┆ 2025-11-0 ┆ null      │
# │ dde-45a9-8 ┆ 5dd-467b-9 ┆ T14:05:16. ┆ Europe    ┆ Gare De   ┆           ┆ 5T14:05:1 ┆           │
# │ 717-df2cf2 ┆ ef1-f4a32b ┆ 469735     ┆           ┆ Lyon      ┆           ┆ 6.469735  ┆           │
# │ …          ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘

# %%
df_bookings.head()
# Out:
# shape: (5, 5)
# ┌──────────────────────────┬──────────────────────────┬────────────────┬──────────────┬────────────┐
# │ booking_id               ┆ search_id                ┆ payment_status ┆ ticket_class ┆ amount_eur │
# │ ---                      ┆ ---                      ┆ ---            ┆ ---          ┆ ---        │
# │ str                      ┆ str                      ┆ str            ┆ str          ┆ f64        │
# ╞══════════════════════════╪══════════════════════════╪════════════════╪══════════════╪════════════╡
# │ e80dc352-ee1b-4c10-b3eb- ┆ 2fc1ab31-20f9-4577-8bed- ┆ Success        ┆ 2nd Class    ┆ 71.81      │
# │ ce93bd…                  ┆ 544797…                  ┆                ┆              ┆            │
# │ 77b36a1f-fe38-4a8c-9af9- ┆ de0dbd1d-85f8-436b-b95f- ┆ Success        ┆ 2nd Class    ┆ 140.79     │
# │ e7cff1…                  ┆ ce4c0f…                  ┆                ┆              ┆            │
# │ c21dffac-e07b-4338-92df- ┆ 2ab924c3-e678-45f6-b838- ┆ Success        ┆ 2nd Class    ┆ 32.69      │
# │ 95cff2…                  ┆ 9248df…                  ┆                ┆              ┆            │
# │ ccb7e082-734b-4644-9997- ┆ f4bb9c14-7546-4df8-87c1- ┆ Success        ┆ 2nd Class    ┆ 60.48      │
# │ 7bd3e4…                  ┆ 91765e…                  ┆                ┆              ┆            │
# │ 06d439ac-a86b-46ec-aaaf- ┆ eb188485-97a9-4903-9521- ┆ Success        ┆ 2nd Class    ┆ 132.07     │
# │ 159bd6…                  ┆ b6e5d8…                  ┆                ┆              ┆            │
# └──────────────────────────┴──────────────────────────┴────────────────┴──────────────┴────────────┘

# %%
df_users.head()
# Out:
# shape: (5, 5)
# ┌─────────────────────────────────┬─────────────┬───────────────────┬─────┬───────────┐
# │ user_id                         ┆ signup_date ┆ subscription_type ┆ age ┆ device_os │
# │ ---                             ┆ ---         ┆ ---               ┆ --- ┆ ---       │
# │ str                             ┆ str         ┆ str               ┆ i64 ┆ str       │
# ╞═════════════════════════════════╪═════════════╪═══════════════════╪═════╪═══════════╡
# │ d4f8a8ea-df0b-4f5b-8589-f8f2bd… ┆ 2024-10-18  ┆ Max Jeune         ┆ 36  ┆ iOS       │
# │ e5d121fd-10fa-4cbb-ac2d-548da5… ┆ 2024-05-28  ┆ Free              ┆ 80  ┆ Unknown   │
# │ 8c606780-bb5b-4167-bb3e-6c5a87… ┆ 2025-11-08  ┆ Free              ┆ 32  ┆ iOS       │
# │ d9848138-7a75-49e1-b1fd-00f6cb… ┆ 2025-01-14  ┆ Free              ┆ 43  ┆ Unknown   │
# │ b568452d-e88d-4b23-b924-c5ef67… ┆ 2024-12-25  ┆ Free              ┆ 39  ┆ Unknown   │
# └─────────────────────────────────┴─────────────┴───────────────────┴─────┴───────────┘

# %% [markdown]
# # **The Global Pulse & Conversion Rate**
#
# 1. **Question:** "How is our business performing day-by-day? What is our global conversion rate?"

# %%
# Create a 'Master Table' (Lef Join Searches -> Bookings)
df_master = (
    df_searches
    .join(df_bookings, on='search_id',how='left')
    .with_columns([
        # Create a boolean flag: Did this search result in a booking?
        pl.col('booking_id').is_not_null().alias('is_converted')
    ])
)

# %%
display(df_master.head())
# Out:
# shape: (5, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ search_id ┆ user_id   ┆ timestamp ┆ origin_st ┆ … ┆ payment_s ┆ ticket_cl ┆ amount_eu ┆ is_conve │
# │ ---       ┆ ---       ┆ ---       ┆ ation     ┆   ┆ tatus     ┆ ass       ┆ r         ┆ rted     │
# │ str       ┆ str       ┆ str       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆ str       ┆   ┆ str       ┆ str       ┆ f64       ┆ bool     │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ fba4f473- ┆ d09d81e5- ┆ 2025-05-1 ┆ Nantes    ┆ … ┆ null      ┆ null      ┆ null      ┆ false    │
# │ c45c-44cb ┆ e17a-416c ┆ 0T11:53:0 ┆           ┆   ┆           ┆           ┆           ┆          │
# │ -a180-f1f ┆ -b37a-a69 ┆ 9.000000  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0c5…      ┆ be0…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ e979d7ef- ┆ bfcade59- ┆ 2025-01-1 ┆ Marseille ┆ … ┆ null      ┆ null      ┆ null      ┆ false    │
# │ 1c14-4bd7 ┆ 80f8-4618 ┆ 8T02:45:5 ┆ St-Charle ┆   ┆           ┆           ┆           ┆          │
# │ -b19e-fbf ┆ -9ccc-de4 ┆ 6.746525  ┆ s         ┆   ┆           ┆           ┆           ┆          │
# │ 76b…      ┆ 4a7…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 529b14cb- ┆ 0f2b800f- ┆ 2025-05-1 ┆ Lyon      ┆ … ┆ Success   ┆ 2nd Class ┆ 78.09     ┆ true     │
# │ 0ed5-4ee0 ┆ 9f10-433e ┆ 4T06:00:0 ┆ Part-Dieu ┆   ┆           ┆           ┆           ┆          │
# │ -9228-e4a ┆ -9998-06d ┆ 0.490315  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 84d…      ┆ 95e…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1b905016- ┆ 5eab057d- ┆ 2025-07-0 ┆ Bordeaux  ┆ … ┆ null      ┆ null      ┆ null      ┆ false    │
# │ 8e6c-4ea4 ┆ 28fa-4bcb ┆ 3T02:35:2 ┆ St-Jean   ┆   ┆           ┆           ┆           ┆          │
# │ -b96c-b4b ┆ -b1ab-a08 ┆ 3.365211  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 9e8…      ┆ a2c…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 10bbab91- ┆ 64f51332- ┆ 2025-10-3 ┆ Lille     ┆ … ┆ null      ┆ null      ┆ null      ┆ false    │
# │ 5dde-45a9 ┆ 15dd-467b ┆ 1T14:05:1 ┆ Europe    ┆   ┆           ┆           ┆           ┆          │
# │ -8717-df2 ┆ -9ef1-f4a ┆ 6.469735  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ cf2…      ┆ 32b…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
daily_stats = (
    df_master
    .with_columns(pl.col('timestamp').str.to_datetime()) # Convert timestamp to datetime
    .sort('timestamp')
    .group_by_dynamic('timestamp',every='1d')
    .agg([
        pl.len().alias('total_searches'),
        pl.col('is_converted').sum().alias('total_bookings'),
        pl.col('amount_eur').sum().alias('total_revenue')
    ])
    .with_columns([
        (pl.col('total_bookings') / pl.col('total_searches')).alias('conversion_rate')
    ])
)

# %%
display(daily_stats.head())
# Out:
# shape: (5, 5)
# ┌─────────────────────┬────────────────┬────────────────┬───────────────┬─────────────────┐
# │ timestamp           ┆ total_searches ┆ total_bookings ┆ total_revenue ┆ conversion_rate │
# │ ---                 ┆ ---            ┆ ---            ┆ ---           ┆ ---             │
# │ datetime[μs]        ┆ u32            ┆ u32            ┆ f64           ┆ f64             │
# ╞═════════════════════╪════════════════╪════════════════╪═══════════════╪═════════════════╡
# │ 2025-01-14 00:00:00 ┆ 38             ┆ 8              ┆ 682.89        ┆ 0.210526        │
# │ 2025-01-15 00:00:00 ┆ 48             ┆ 15             ┆ 1429.85       ┆ 0.3125          │
# │ 2025-01-16 00:00:00 ┆ 44             ┆ 15             ┆ 1280.15       ┆ 0.340909        │
# │ 2025-01-17 00:00:00 ┆ 38             ┆ 11             ┆ 743.93        ┆ 0.289474        │
# │ 2025-01-18 00:00:00 ┆ 43             ┆ 13             ┆ 781.3         ┆ 0.302326        │
# └─────────────────────┴────────────────┴────────────────┴───────────────┴─────────────────┘

# %% [markdown]
# # **Visualization: Dual Axis Line Chart (Searches vs Conversion)**

# %%
fig_pulse = px.line(
    daily_stats.to_pandas(),
    x='timestamp',
    y='total_searches',
    title= 'Daily Search Volumn',
    labels = {'total_searches':'Total Searches','timestamp':'Month'}
)

fig_pulse.add_bar(
    x=daily_stats['timestamp'],
    y=daily_stats['conversion_rate'],
    name='Conversion Rate'
)

fig_pulse.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1a8af135-a1ee-41b3-8a4a-7e5389e9701b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a8af135-a1ee-41b3-8a4a-7e5389e9701b")) {                    Plotly.newPlot(                        "1a8af135-a1ee-41b3-8a4a-7e5389e9701b",                        [{"hovertemplate":"Month=%{x}\u003cbr\u003eTotal Searches=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2025-01-14T00:00:00","2025-01-15T00:00:00","2025-01-16T00:00:00","2025-01-17T00:00:00","2025-01-18T00:00:00","2025-01-19T00:00:00","2025-01-20T00:00:00","2025-01-21T00:00:00","2025-01-22T00:00:00","2025-01-23T00:00:00","2025-01-24T00:00:00","2025-01-25T00:00:00","2025-01-26T00:00:00","2025-01-27T00:00:00","2025-01-28T00:00:00","2025-01-29T00:00:00","2025-01-30T00:00:00","2025-01-31T00:00:00","2025-02-01T00:00:00","2025-02-02T00:00:00","2025-02-03T00:00:00","2025-02-04T00:00:00","2025-02-05T00:00:00","2025-02-06T00:00:00","2025-02-07T00:00:00","2025-02-08T00:00:00","2025-02-09T00:00:00","2025-02-10T00:00:00","2025-02-11T00:00:00","2025-02-12T00:00:00","2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00","2025-05-14T00:00:00","2025-05-15T00:00:00","2025-05-16T00:00:00","2025-05-17T00:00:00","2025-05-18T00:00:00","2025-05-19T00:00:00","2025-05-20T00:00:00","2025-05-21T00:00:00","2025-05-22T00:00:00","2025-05-23T00:00:00","2025-05-24T00:00:00","2025-05-25T00:00:00","2025-05-26T00:00:00","2025-05-27T00:00:00","2025-05-28T00:00:00","2025-05-29T00:00:00","2025-05-30T00:00:00","2025-05-31T00:00:00","2025-06-01T00:00:00","2025-06-02T00:00:00","2025-06-03T00:00:00","2025-06-04T00:00:00","2025-06-05T00:00:00","2025-06-06T00:00:00","2025-06-0 ...

# %% [markdown]
# # **The Route Matrix (Heatmap)**
#
# **Question:** Which routes are our bread and butter? Are there routes with high demand but low supply (or low conversion)?"

# %%
# Counting the searches per Origin-Destination pair
route_stats = (
    df_searches
    .group_by(['origin_station','destination_station'])
    .len()
    .rename({'len':'search_count'})
    .sort('search_count',descending=True)
)

# %%
display(route_stats.head())
# Out:
# shape: (5, 3)
# ┌──────────────────────┬──────────────────────┬──────────────┐
# │ origin_station       ┆ destination_station  ┆ search_count │
# │ ---                  ┆ ---                  ┆ ---          │
# │ str                  ┆ str                  ┆ u32          │
# ╞══════════════════════╪══════════════════════╪══════════════╡
# │ Bordeaux St-Jean     ┆ Strasbourg           ┆ 343          │
# │ Nantes               ┆ Lille Europe         ┆ 339          │
# │ Strasbourg           ┆ Marseille St-Charles ┆ 339          │
# │ Lyon Part-Dieu       ┆ Strasbourg           ┆ 335          │
# │ Marseille St-Charles ┆ Nantes               ┆ 335          │
# └──────────────────────┴──────────────────────┴──────────────┘

# %%
# Pivot for Heatmap format (Origin as Rows, Destination as Columns)
route_matrix = (
    route_stats
    .pivot(values='search_count',index='origin_station',columns='destination_station')
    .fill_null(0) # Fill routes with 0 searches
)
# Out:
# /tmp/ipython-input-439793284.py:4: DeprecationWarning:
#
# the argument `columns` for `DataFrame.pivot` is deprecated. It was renamed to `on` in version 1.0.0.

# %%
display(route_matrix.head())
# Out:
# shape: (5, 8)
# ┌─────────────┬─────────────┬────────┬─────────────┬────────┬────────────┬────────────┬────────────┐
# │ origin_stat ┆ Strasbourg  ┆ Lille  ┆ Marseille   ┆ Nantes ┆ Paris Gare ┆ Bordeaux   ┆ Lyon       │
# │ ion         ┆ ---         ┆ Europe ┆ St-Charles  ┆ ---    ┆ De Lyon    ┆ St-Jean    ┆ Part-Dieu  │
# │ ---         ┆ u32         ┆ ---    ┆ ---         ┆ u32    ┆ ---        ┆ ---        ┆ ---        │
# │ str         ┆             ┆ u32    ┆ u32         ┆        ┆ u32        ┆ u32        ┆ u32        │
# ╞═════════════╪═════════════╪════════╪═════════════╪════════╪════════════╪════════════╪════════════╡
# │ Bordeaux    ┆ 343         ┆ 327    ┆ 295         ┆ 334    ┆ 300        ┆ 302        ┆ 306        │
# │ St-Jean     ┆             ┆        ┆             ┆        ┆            ┆            ┆            │
# │ Nantes      ┆ 314         ┆ 339    ┆ 324         ┆ 302    ┆ 304        ┆ 274        ┆ 298        │
# │ Strasbourg  ┆ 294         ┆ 316    ┆ 339         ┆ 316    ┆ 331        ┆ 263        ┆ 322        │
# │ Lyon        ┆ 335         ┆ 325    ┆ 280         ┆ 310    ┆ 290        ┆ 328        ┆ 326        │
# │ Part-Dieu   ┆             ┆        ┆             ┆        ┆            ┆            ┆            │
# │ Marseille   ┆ 294         ┆ 297    ┆ 276         ┆ 335    ┆ 318        ┆ 280        ┆ 304        │
# │ St-Charles  ┆             ┆        ┆             ┆        ┆            ┆            ┆            │
# └─────────────┴─────────────┴────────┴─────────────┴────────┴────────────┴────────────┴────────────┘

# %%
fig_routes = px.imshow(
    route_matrix.to_pandas().set_index('origin_station'),
    text_auto=True,
    title='Search Volume Heatmap: Origin vs Destination',
    color_continuous_scale = 'Viridis',
    labels= {'origin_station': 'Origin Station'}
)

fig_routes.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cbbc73f4-20d6-40de-a45a-8f05c7242703" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbbc73f4-20d6-40de-a45a-8f05c7242703")) {                    Plotly.newPlot(                        "cbbc73f4-20d6-40de-a45a-8f05c7242703",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["Strasbourg","Lille Europe","Marseille St-Charles","Nantes","Paris Gare De Lyon","Bordeaux St-Jean","Lyon Part-Dieu"],"y":["Bordeaux St-Jean","Nantes","Strasbourg","Lyon Part-Dieu","Marseille St-Charles","Lille Europe","Paris Gare De Lyon"],"z":[[343,327,295,334,300,302,306],[314,339,324,302,304,274,298],[294,316,339,316,331,263,322],[335,325,280,310,290,328,326],[294,297,276,335,318,280,304],[314,288,307,272,323,313,257],[279,315,280,288,301,320,302]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003eorigin_station: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"col ...

# %% [markdown]
# # **Price Sensitivity & Lead Time**
#
# **Question:** Do people who book far in advance pay less? Does the price distribution differ by Ticket Class?

# %%
price_analysis = (
    df_master
    .filter(pl.col('is_converted')) # Only look at actual bookings
    .with_columns([
        pl.col('departure_date').str.to_datetime(), # Convert to datetime
        pl.col('timestamp').str.to_datetime()       # Convert to datetime
    ])
    .with_columns([
        (pl.col('departure_date') - pl.col('timestamp')).dt.total_days().alias('days_advance')
    ])
    .filter(pl.col('days_advance') >= 0) # A safety filter
)

# %%
display(price_analysis.head())
# Out:
# shape: (5, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ search_id ┆ user_id   ┆ timestamp ┆ origin_st ┆ … ┆ ticket_cl ┆ amount_eu ┆ is_conver ┆ days_adv │
# │ ---       ┆ ---       ┆ ---       ┆ ation     ┆   ┆ ass       ┆ r         ┆ ted       ┆ ance     │
# │ str       ┆ str       ┆ datetime[ ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ μs]       ┆ str       ┆   ┆ str       ┆ f64       ┆ bool      ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 529b14cb- ┆ 0f2b800f- ┆ 2025-05-1 ┆ Lyon      ┆ … ┆ 2nd Class ┆ 78.09     ┆ true      ┆ 7        │
# │ 0ed5-4ee0 ┆ 9f10-433e ┆ 4 06:00:0 ┆ Part-Dieu ┆   ┆           ┆           ┆           ┆          │
# │ -9228-e4a ┆ -9998-06d ┆ 0.490315  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 84d…      ┆ 95e…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 9b97a019- ┆ dee0d056- ┆ 2025-12-0 ┆ Paris     ┆ … ┆ 2nd Class ┆ 80.77     ┆ true      ┆ 1        │
# │ 5ba3-4c38 ┆ 732a-41dc ┆ 8 09:23:0 ┆ Gare De   ┆   ┆           ┆           ┆           ┆          │
# │ -8c7b-57c ┆ -a91c-8e0 ┆ 2.316447  ┆ Lyon      ┆   ┆           ┆           ┆           ┆          │
# │ 7a7…      ┆ fb6…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ bba41b7b- ┆ 62abe694- ┆ 2025-06-0 ┆ Strasbour ┆ … ┆ 2nd Class ┆ 133.09    ┆ true      ┆ 20       │
# │ b271-4dc0 ┆ d577-4c54 ┆ 3 23:12:2 ┆ g         ┆   ┆           ┆           ┆           ┆          │
# │ -b37a-a95 ┆ -922d-3f2 ┆ 5.705854  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 432…      ┆ 341…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 59c62e92- ┆ 4cf05f28- ┆ 2025-08-2 ┆ Bordeaux  ┆ … ┆ 1st Class ┆ 120.09    ┆ true      ┆ 28       │
# │ f03d-4316 ┆ b67f-4adc ┆ 1 22:27:4 ┆ St-Jean   ┆   ┆           ┆           ┆           ┆          │
# │ -aaa5-e87 ┆ -9332-b9f ┆ 0.032473  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ dee…      ┆ b36…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 6269f53f- ┆ ec5f2f3d- ┆ 2025-11-0 ┆ Paris     ┆ … ┆ 2nd Class ┆ 30.71     ┆ true      ┆ 3        │
# │ 6d6a-47f0 ┆ e881-44db ┆ 3         ┆ Gare De   ┆   ┆           ┆           ┆           ┆          │
# │ -b6e2-c40 ┆ -a5e0-a85 ┆ 07:42:22  ┆ Lyon      ┆   ┆           ┆           ┆           ┆          │
# │ cd3…      ┆ 366…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Average Price per Ticket Class
class_pricing = (
    price_analysis
    .group_by('ticket_class')
    .agg([
        pl.col('amount_eur').mean().alias('avg_price'),
        pl.col('amount_eur').median().alias('median_price'),
        pl.len().alias('count')
    ])
)

# %%
display(class_pricing.head())
# Out:
# shape: (2, 4)
# ┌──────────────┬───────────┬──────────────┬───────┐
# │ ticket_class ┆ avg_price ┆ median_price ┆ count │
# │ ---          ┆ ---       ┆ ---          ┆ ---   │
# │ str          ┆ f64       ┆ f64          ┆ u32   │
# ╞══════════════╪═══════════╪══════════════╪═══════╡
# │ 2nd Class    ┆ 86.77517  ┆ 86.88        ┆ 3199  │
# │ 1st Class    ┆ 88.20613  ┆ 89.12        ┆ 801   │
# └──────────────┴───────────┴──────────────┴───────┘

# %%
fig_price_distribution = px.box(
    price_analysis.to_pandas(),
    x='ticket_class',
    y='amount_eur',
    color='ticket_class',
    title='Price Distribution by Ticket Class',
    labels = {'ticket_class':'Ticket Class','amount_eur':'Amount (EUR)'}
)

fig_price_distribution.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35a48ce2-0635-4d89-afd4-96dc65c57c5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35a48ce2-0635-4d89-afd4-96dc65c57c5a")) {                    Plotly.newPlot(                        "35a48ce2-0635-4d89-afd4-96dc65c57c5a",                        [{"alignmentgroup":"True","hovertemplate":"Ticket Class=%{x}\u003cbr\u003eAmount (EUR)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2nd Class","marker":{"color":"#636efa"},"name":"2nd Class","notched":false,"offsetgroup":"2nd Class","orientation":"v","showlegend":true,"x":["2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2nd Class","2n ...

# %% [markdown]
# # **Are last-minute tickets more expensive?**

# %%
fig_price = px.scatter(
    price_analysis.sample(n=1000, with_replacement=True).to_pandas(), # Sample to avoid overcrowding
    x='days_advance',
    y='amount_eur',
    color='ticket_class',
    title='Does booking early save money?',
    labels={'amount_eur':'Amount (EUR)','days_advance':'Days booked in advance','ticket_class':'Ticket Class'}
)
fig_price.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e8aeadb5-f93d-4ba3-8886-944bc222ffab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8aeadb5-f93d-4ba3-8886-944bc222ffab")) {                    Plotly.newPlot(                        "e8aeadb5-f93d-4ba3-8886-944bc222ffab",                        [{"hovertemplate":"Ticket Class=2nd Class\u003cbr\u003eDays booked in advance=%{x}\u003cbr\u003eAmount (EUR)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2nd Class","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"2nd Class","orientation":"v","showlegend":true,"x":[22,10,2,10,24,9,13,1,12,2,26,15,28,27,8,26,16,24,2,1,11,16,17,9,10,0,25,27,18,20,25,25,8,19,23,19,15,10,13,7,23,21,9,25,27,10,2,26,11,7,23,10,28,14,6,14,0,7,25,29,15,23,21,26,28,8,0,18,24,13,19,14,21,25,13,15,5,21,20,11,28,0,15,5,16,22,4,18,10,15,14,10,24,5,14,10,28,1,15,13,0,4,24,25,0,15,24,5,19,2,17,20,14,2,10,1,8,15,20,11,18,3,26,18,4,24,21,23,8,6,25,13,13,10,4,3,17,10,29,11,13,18,9,16,18,3,23,20,27,29,29,1,10,27,13,1,13,22,28,0,8,29,7,17,0,15,5,15,10,14,14,17,28,9,19,14,19,25,12,0,0,16,11,26,22,24,13,16,8,18,14,5,16,19,20,22,10,27,23,5,3,28,4,4,24,24,10,21,11,7,16,17,12,27,21,12,18,25,0,9,6,18,2,15,16,25,28,28,8,8,4,21,14,27,28,24,22,12,14,21,0,18,12,17,2,21,16,17,0,0,19,23,29,3,16,13,7,25,23,8,4,27,28,12,23,18,17,3,29,28,10,12,26,20,4,0,16,4,22,14,12,20,15,15,20,8,3,18,0,13,22,11,27,29,3,4,13,4,26,25,0,8,26,5,1,14,4,13,26,11,27,4,4,14,18,28,21,6,3,8,24,15,12,9,28,27,22,1,10,2,28,2,8,18,21,8,16,20,21,12,11,23,26,15,13,2,4,19,14,9,18,17,29,23,15,14,25,26,0,5,17,2,10,27,10,25,19,22,15,13,18,9,19,18,9,1,15,27,8,21,25,2,20,21,9,25,28,21,25,29,17,4,2,11,27,8,9,29,3,17,12,22,12,25,1,18,1,7,16,21,10,24,17,28,4,21,2,28,0,10,19,22,5,2,22,11,1,12,0,8,29,6,19,20,3,25,24,26,23,7,23,19,12,0,0,21,1,4,11,27,8,16,11,20,2,4,29,19,24,24,9,5,0,10,16,9,2,13,26,25,3,4,19,9,13,13,18,0,8,2,2,1,29,17,3,15,17,4,19,6,18,7,0,12,18,17,4,20,17,8,10,2,7,24,23,27,14,26,5,24,2,23,10,12,2,12,24,27,21,18,27,13,25,5,24,19,5,28,10,22,15,1,0,4,12,20,29,2,20,25,10,17,3,6,3,13,28,22,7,5,1,19,29,3,27,20,15,12,21,19,12,11,27,21,29,15,3,28,24,15,26,25,6,7,9,14,10,15,29,15,22,11,20,6,1,27,16,19,14,26,7,13,19,23,2,2,9,15,9,6,7,26,12,12,7,0,3,8,14,26,13,17,26,28,1,0,21,6,19,11,25,28,2,8,11,10,15,17,22,13,9,12,29,20,27,6,9,7,19,7,24,16,19,3,24,1,18,0,26,19,7,15,25,24,13,12,13,7,4,26,25,28,17,17,24,3,29,14,21,14,7,13,6,5,1,15,26,8,24,6,28,25,12,15,16,10,21,4,4,6,6,27,15,9,16,26,8,5,27,18,0,2,5,14,19,20,8,5,7,0,24,0,11,10,16,21,3,23,26,24,14,26,6,1,18,3,13,0,19,0,11,22,23,27,24,14,24,26,26,24,14,18,20,21,8,14,1,15,11,25,10,13,5,28,26,26,14,0,2,15,21,26,17,6,27,16,3,10,8,4,11,23,16,3,21,6,20,18,9,5,24,17,8,16,21,2,29,9,22,5,29,7,13,17,20,27,0,28],"xaxis":"x","y":[61.65,25.54,52.25,79.33,111.24,144.72,33.49,130.57,40.95,130.07,127.99,149.26,130.8,28.05,99.89,32.56,88.92,27.04,116.2,132.42,63.55,90.53,104.68,136.27,107.86,56.95,86.48,68.26,88.76,118.96,149.35,144.05,88.47,57.62,66.51,96.41,115.04,113.05,78.92,25.85,96.68,128.09,39.72,88.74,98.98,124.8,126.83,48.39,74.8,134.61,130.48,50.04,117.65,57.01,83.99,89.36,28.21,78.38,58.45,37.68,44.7,125.68,95.03,46.92,130.8,32.93,55.11,79.49,76.86,84.32,26.88,53.52,100.25,63.66,66.69,72.36,48.72,115.04,69.66,63.55,108.14,28.56,143.66,132.21,57.76,119.91,144.17,35.15,144.82,149.74,47.2,32.58,44.18,72.92,84.14,26.04,58.63,80.77,75.92,63.01,89.32,144.17,80.82,73.66,109.07,76.03,148.18,59.56,100.1,32.88,122.07,118.28,113.36,92.72,121.55,112.69,69.39,139.8,44.16,84.09,62.48,83.54,81.57,26.95,33.72,51.06,97.01,64.29,85.9,87.42,44.56,68.28,117.32,35.95,109.81,131.13,72.23,145.32,105.69,145.75,68.89,42.77,31.13,40.21,49.81,69.03,107.71,70.19,142.65,31.1,37.88,135.07,60.04,133.71,128.11,4 ...
